# %% [markdown]
# # Introduction
# The job finding industry has evovled from "help wanted" signs hung outside of stores, to a section in the newspaper devoted to job posts to what we have now, websites that connect employers to applicants. Due to the efficiency of these sites, most people looking for a job have to cast a wide net and apply to hundreds of jobs to even get an interview. With job posts being missleading it can feel like you are spending more time looking for positions to apply to rather than applying. This inefficiecy happens for a few reasons. The category "entry level" encompasses many positions from those that are specifically for newly graduating seniors to others that require canditits to have at up to 5+ years of industry experience. This means filtering for entry level positions is not helpful. As well, the key word searching that most job sites have return results that can match any level of experience. Looking up "Software Engineer" may include senior level positions, mid level positions and entry level positions. At the end of the day, a lot of time is wasted reading through job descriptions to find that they do not match what you are looking for, when that time could be used to applying to another position in which you may be qualified for.
#
#
# # The Approach
# In the evolution of the job finding industry, from "help wanted" signs to sophisticated online platforms, the quest for efficiency and accuracy in connecting job seekers with suitable positions remains paramount. The current landscape, characterized by the need to sift through hundreds of job postings due to misleading titles and broad categorization, underscores the necessity for a refined approach. This essay draws upon recent research to justify an innovative method aimed at streamlining the job search process, leveraging advancements in Natural Language Processing (NLP) and Machine Learning (ML) to address inherent inefficiencies.
#
# The foundational piece of this discussion, "NLP Techniques for Job Market Trend Analysis," provides insight into how NLP can be utilized to dissect and understand complex job descriptions. By analyzing the semantics and structure of job postings, NLP techniques can categorize positions more accurately than traditional keyword-based searches. This nuanced understanding allows for the differentiation between truly entry-level roles and those requiring significant experience, thus enabling job seekers to navigate listings more effectively and apply to positions that match their qualifications and career stage.
#
# Furthermore, the "Skills and Requirements" document underscores the importance of aligning job seekers' skills with employer expectations. A detailed examination of common requirements across various industries reveals the gap between job descriptions and the actual skills needed for a position. By integrating these insights into job matching platforms, it's possible to develop more precise filters and recommendations, guiding applicants toward opportunities where they are most likely to succeed and fulfill employers' expectations.
#
# The most compelling argument for the proposed approach comes from "Machine Learning and Job Posting Classification: A Comparative Study," which explores the application of ML classifiers in distinguishing real from fake job postings. Beyond this primary function, these classifiers hold the potential for categorizing jobs into detailed levels and types based on the requirements and experience needed. Implementing such a classification system can dramatically improve the job search experience, moving beyond the limitations of keyword searches to offer a curated list of opportunities tailored to each job seeker's profile.
#
# The integration of NLP and ML into the job finding process addresses two primary challenges: the broad and often misleading categorization of "entry level" positions and the inefficiency of keyword-based searches. By accurately interpreting job descriptions and requirements, the proposed method ensures that job seekers spend less time filtering through irrelevant postings and more time applying to positions for which they are well-suited. Moreover, by classifying postings based on detailed criteria, platforms can offer personalized recommendations, further enhancing the efficiency of the job search process.
#
# In conclusion, the transition to a more sophisticated job finding mechanism, underpinned by NLP and ML, represents a significant leap forward in matching job seekers with suitable employment opportunities. This approach not only mitigates the challenges posed by traditional job search methods but also aligns with the evolving dynamics of the labor market. By leveraging the insights and techniques outlined in the aforementioned research, the proposed project stands to offer a more streamlined, accurate, and user-friendly job search experience, marking a pivotal advancement in the industry's ongoing evolution.
#
# # The Dataset
# The dataset that will be used to train this model will be created by using Jobspy. Jobspy is open source program that scrapes job postings from various websites. The dataset will consist of job postings from Linkedin, Indeed, Zip Recruiter, and Glassdoor and will be the results of looking up "entry level software developer," "new graduate software developer," and "junior software engineer" as these search results will have the highest correlation to jobs that require canditits to have no industry experience. The dataset is ever growing as when the program is run the results are saved and appended to the previous dataset. This means that it will contain real word job postings. Also I used software developer as this is what closely relates to me, but you can change it to any search input.
#
# Jobspy: https://github.com/Bunsly/JobSpy

# %%
pip install -U python-jobspy
# Out:
# Requirement already satisfied: python-jobspy in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (1.1.51)
# Requirement already satisfied: NUMPY==1.24.2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from python-jobspy) (1.24.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from python-jobspy) (4.12.3)
# Requirement already satisfied: markdownify<0.12.0,>=0.11.6 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from python-jobspy) (0.11.6)
# Requirement already satisfied: pandas<3.0.0,>=2.1.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from python-jobspy) (2.2.1)
# Collecting pydantic<3.0.0,>=2.3.0 (from python-jobspy)
#   Downloading pydantic-2.7.0-py3-none-any.whl.metadata (103 kB)
#      ---------------------------------------- 0.0/103.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/103.4 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/103.4 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 103.4/103.4 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from python-jobspy) (2.31.0)
# Requirement already satisfied: tls-client<2.0.0,>=1.0.1 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from python-jobspy) (1.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy) (2.5)
# Requirement already satisfied: six<2,>=1.15 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from markdownify<0.12.0,>=0.11.6->python-jobspy) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (0.6.0)
# Collecting pydantic-core==2.18.1 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Downloading pydantic_core-2.18.1-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2024.2.2)
# Downloading pydantic-2.7.0-py3-none-any.whl (407 kB)
#    ---------------------------------------- 0.0/407.9 kB ? eta -:--:--
#    --------------------------------------  399.4/407.9 kB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 407.9/407.9 kB 8.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.1-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ------------- -------------------------- 0.6/1.9 MB 20.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.4/1.9 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 15.2 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, pydantic
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.3
#     Uninstalling pydantic_core-2.16.3:
#       Successfully uninstalled pydantic_core-2.16.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.15
#     Uninstalling pydantic-1.10.15:
#       Successfully uninstalled pydantic-1.10.15
# Successfully installed pydantic-2.7.0 pydantic-core-2.18.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# farm-haystack 1.25.2 requires pydantic<2, but you have pydantic 2.7.0 which is incompatible.

# %%
from jobspy import scrape_jobs
import pandas as pd
import time

# %%
 jobs1: pd.DataFrame = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="entry level software developer",
    hours_old=24,
    results_wanted=25,  # be wary the higher it is, the more likey you'll get blocked (rotating proxy can help tho)
    country_indeed="USA",
    # proxy="http://jobspy:5a4vpWtj8EeJ2hoYzk@ca.smartproxy.com:20001",
)

time.sleep(30)

jobs2: pd.DataFrame = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="new graduate software developer",
    hours_old=24,
    results_wanted=25,  # be wary the higher it is, the more likey you'll get blocked (rotating proxy can help tho)
    country_indeed="USA",
    # proxy="http://jobspy:5a4vpWtj8EeJ2hoYzk@ca.smartproxy.com:20001",
)

time.sleep(30)

jobs3: pd.DataFrame = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="junior software engineer",
    hours_old=24,
    results_wanted=25,  # be wary the higher it is, the more likey you'll get blocked (rotating proxy can help tho)
    country_indeed="USA",
    # proxy="http://jobspy:5a4vpWtj8EeJ2hoYzk@ca.smartproxy.com:20001",
)


# formatting for pandas
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", 50)  # set to 0 to see full job url / desc


print(jobs1)
# Out:
# 2024-04-12 17:17:10,486 - JobSpy - INFO - Indeed search page: 1
# 2024-04-12 17:17:10,491 - JobSpy - INFO - LinkedIn search page: 1
# 2024-04-12 17:17:10,658 - JobSpy - INFO - ZipRecruiter search page: 1
# 2024-04-12 17:17:11,104 - JobSpy - INFO - ZipRecruiter finished scraping
# 2024-04-12 17:17:11,844 - JobSpy - INFO - Indeed finished scraping
# 2024-04-12 17:17:48,773 - JobSpy - INFO - LinkedIn search page: 2
# 2024-04-12 17:17:55,879 - JobSpy - INFO - LinkedIn search page: 3
# 2024-04-12 17:17:57,232 - JobSpy - INFO - Linkedin finished scraping
# ---------------------------------------------------------------------------
# TLSClientExeption                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 jobs1: pd.DataFrame = scrape_jobs(
#       2    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
#       3    search_term="entry level software developer",
#       4    hours_old=24,
#       5    results_wanted=25,  # be wary the higher it is, the more likey you'll get blocked (rotating proxy can help tho)
#       6    country_indeed="USA",
#       7    # proxy="http://jobspy:5a4vpWtj8EeJ2hoYzk@ca.smartproxy.com:20001",
#       8 )
#      10 time.sleep(30)
#      12 jobs2: pd.DataFrame = scrape_jobs(
#      13    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
#      14    search_term="new graduate software developer",
#    (...)
#      18    # proxy="http://jobspy:5a4vpWtj8EeJ2hoYzk@ca.smartproxy.com:20001",
#      19 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\jobspy\__init__.py:118, in scrape_jobs(site_name, search_term, location, distance, is_remote, job_type, easy_apply, results_wanted, country_indeed, hyperlinks, proxy, description_format, linkedin_fetch_description, linkedin_company_ids, offset, hours_old, verbose, **kwargs)
#     113     future_to_site = {
#     114         executor.submit(worker, site): site for site in scraper_input.site_type
#     115     }
#     117     for future in as_completed(future_to_site):
# --> 118         site_value, scraped_data = future.result()
#     119         site_to_jobs_dict[site_value] = scraped_data
#     121 jobs_dfs: list[pd.DataFrame] = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\jobspy\__init__.py:109, in scrape_jobs.<locals>.worker(site)
#     108 def worker(site):
# --> 109     site_val, scraped_info = scrape_site(site)
#     110     return site_val, scraped_info
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\jobspy\__init__.py:100, in scrape_jobs.<locals>.scrape_site(site)
#      98 scraper_class = SCRAPER_MAPPING[site]
#      99 scraper = scraper_class(proxy=proxy)
# --> 100 scraped_data: JobResponse = scraper.scrape(scraper_input)
#     101 cap_name = site.value.capitalize()
#     102 site_name = "ZipRecruiter" if cap_name == "Zip_recruiter" else cap_name
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\jobspy\scrapers\glassdoor\__init__.py:63, in GlassdoorScraper.scrape(self, scraper_input)
#      60 self.base_url = self.scraper_input.country.get_glassdoor_url()
#      62 self.session = create_session(self.proxy, is_tls=True, has_retry=True)
# ---> 63 token = self._get_csrf_token()
#      64 self.headers["gd-csrf-token"] = token if token else self.fallback_token
#      66 location_id, location_type = self._get_location(
#      67     scraper_input.location, scraper_input.is_remote
#      68 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\jobspy\scrapers\glassdoor\__init__.py:151, in GlassdoorScraper._get_csrf_token(self)
#     147 def _get_csrf_token(self):
#     148     """
#     149     Fetches csrf token needed for API by visiting a generic page
#     150     """
# --> 151     res = self.session.get(
#     152         f"{self.base_url}/Job/computer-science-jobs.htm", headers=self.headers
#     153     )
#     154     pattern = r'"token":\s*"([^"]+)"'
#     155     matches = re.findall(pattern, res.text)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tls_client\sessions.py:459, in Session.get(self, url, **kwargs)
#     453 def get(
#     454     self,
#     455     url: str,
#     456     **kwargs: Any
#     457 ) -> Response:
#     458     """Sends a GET request"""
# --> 459     return self.execute_request(method="GET", url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tls_client\sessions.py:442, in Session.execute_request(self, method, url, params, data, headers, cookies, json, allow_redirects, insecure_skip_verify, timeout_seconds, proxy)
#     439 # --- Response -------------------------------------------------------------------------------------------------
#     440 # Error handling
#     441 if response_object["status"] == 0:
# --> 442     raise TLSClientExeption(response_object["body"])
#     443 # Set response cookies
#     444 response_cookie_jar = extract_cookies_to_jar(
#     445     request_url=url,
#     446     request_headers=headers,
#     447     cookie_jar=cookies,
#     448     response_headers=response_object["headers"]
#     449 )
#
# TLSClientExeption: failed to do request: Get "https://www.glassdoor.com//Job/computer-science-jobs.htm": net/http: request canceled (Client.Timeout exceeded while awaiting headers)

# %% [markdown]
# # EDA
# We will now preform an EDA to get a better understanding of our data. As well, we will clean the data. This will happen in two parts as the NLP step requires us to only care about duplicates, and the quality of the description. After deleting duplicates, we will clean the description by checking to see if the web scraper got the whole description and removing HTML code. We will also add the title of the position to the description so that we can use that data to further understand the job posting. Lastly, we will remove any fields that are not necessary for training the model.

# %%
existing_data = pd.read_json("./jobs.json", lines=True)
#jobs = pd.concat([jobs1, jobs2, jobs3, existing_data], ignore_index=True)
jobs.shape
# Out:
# (441, 30)

# %%
jobs = jobs.drop_duplicates()
jobs.to_json('./jobs.json', orient='records', lines=True)

# %%
jobs.shape
# Out:
# (441, 30)

# %%
jobs.head(50)
# Out:
#              site                                            job_url  \
# 0       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 1       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 2       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 3       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 4       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 5       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 6       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 7       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 8       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 9       glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 10      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 11      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 12      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 13      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 14      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 15      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 16      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 17      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 18      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 19      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 20      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 21      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 22      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 23      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 24      glassdoor  https://www.glassdoor.com/job-listing/j?jl=100...
# 25         indeed  https://www.indeed.com/viewjob?jk=8f310d5edbaa...
# 26         indeed  https://www.indeed.com/viewjob?jk=2c330faf66c5...
# 27         indeed  https://www.indeed.com/viewjob?jk=f71d211b41f9...
# 28         indeed  https://www.indeed.com/viewjob?jk=77d6f959751e...
# 29         indeed  https://www.indeed.com/viewjob?jk=893a57d03203...
# 30         indeed  https://www.indeed.com/viewjob?jk=905f72133823...
# 31         indeed  https://www.indeed.com/viewjob?jk=eaf66b414ea2...
# 32         indeed  https://www.indeed.com/viewjob?jk=6152c3cd1500...
# 33         indeed  https://www.indeed.com/viewjob?jk=eeca43460449...
# 34         indeed  https://www.indeed.com/viewjob?jk=30492bd0f352...
# 35         indeed  https://www.indeed.com/viewjob?jk=e80b40cc2bf9...
# 36         indeed  https://www.indeed.com/viewjob?jk=a3ed5bd3d32c...
# 37         indeed  https://www.indeed.com/viewjob?jk=59a3f5172b81...
# 38         indeed  https://www.indeed.com/viewjob?jk=3c7dde041663...
# 39         indeed  https://www.indeed.com/viewjob?jk=2f26bf7b16e9...
# 40         indeed  https://www.indeed.com/viewjob?jk=039821b52908...
# 41         indeed  https://www.indeed.com/viewjob?jk=5aca6c283727...
# 42         indeed  https://www.indeed.com/viewjob?jk=a1227f374fb2...
# 43         indeed  https://www.indeed.com/viewjob?jk=79a1bee2eebb...
# 36                                     .Net Developer
# 37  Geographical Information System (GIS) Develope...
# 38            Associate Manager, Software Development
# 39                              Intern- PHP Developer
# 40        ServiceNow Developer - TS/SCI Poly Required
# 41                      DATA BASE ADMINISTRATOR - SES
# 42                            Senior Traffic Engineer
# 43                                          Planner 1
# 44                               Development Engineer
# 45                      Clinical Research Coordinator
# 46   Associate Software Engineer (Remote Opportunity)
# 47  Project Delivery Specialist - PostgreSQL Devel...
# 73                   React Developer (No C2C)- REMOTE
# 74                           .Net FullStack Developer
#
#                                    company              location  \
# 0                 Penguin Random House LLC         United States
# 1                        Harbor Compliance                   NaN
# 2                               ProIT Inc.                   NaN
# 3                                   Omatic                   NaN
# 4                      Insight Enterprises  Saint Petersburg, FL
# 5                                  Zipline                   NaN
# 6                            Data Concepts        Glen Allen, VA
# 7                            IT-SCIENT LLC                   NaN
# 8                              CrowdStrike                   NaN
# 9                   Zero Gravity Marketing                   NaN
# 10                                     EBQ            Austin, TX
# 11                  Zero Gravity Marketing                   NaN
# 12                               Aerostrat                   NaN
# 13                            Togetherwork           Atlanta, GA
# 14         Zoom Video Communications, Inc.                   NaN
# 15                           Swanktek, Inc                   NaN
# 16                RYNO Strategic Solutions                   NaN
# 17                                   Optum      Eden Prairie, MN
# 18                                 Higharc                   NaN
# 19                                 Cofactr                   NaN
# 20                      TENTH MOUNTAIN LLC                   NaN
# 21                     Eleventh Hour Games            Dallas, TX
# 22                              Ad Hoc LLC        Washington, DC
# 23                            HealthEquity                   NaN
# 24  American Recruiting & Consulting Group                   NaN
# 25                          HCA Healthcare     Nashville, TN, US
# 26                    Omni NY & Affiliates         Tulsa, OK, US
# 27                          HCA Healthcare      Franklin, TN, US
# 28        Contact Government Services, LLC        Denver, CO, US
# 29                           CITY OF TRACY         Tracy, CA, US
# 30                                Deloitte                    US
# 31                                Deloitte                    US
# 32       ManTech International Corporation            Remote, US
# 33                             BAE Systems        McLean, VA, US
# 34                    GSL Properties, Inc.   Lake Oswego, OR, US
# 35                       Marion County, OR         Salem, OR, US
# 36                    Cloud and Things Inc      New York, NY, US
# 37              R.L.B Alliance DBA Teckjet      New York, NY, US
# 38  Open Systems International, Inc. (OSI)        Medina, MN, US
# 39                               illumifin  Eden Prairie, MN, US
# 40                                Deloitte     Baltimore, MD, US
# 41                        State of Florida   Tallahassee, FL, US
# 42                                     WSP   Glastonbury, CT, US
# 43                        Town of Milliken      Milliken, CO, US
# 44                     ECCV Water District        Aurora, CO, US
# 45                                    AXLE     Rockville, MD, US
# 46                         Greenway Health            Remote, US
# 47                                Deloitte                    US
# 73                                   Xlysi      Chicago, IL, USA
# 74                              PamTen Inc   Schaumburg, IL, USA
#
#               job_type date_posted interval  min_amount  max_amount currency  \
# 0                  NaN  2024-03-30   yearly   130000.00   135000.00      USD
# 1                  NaN  2024-03-30      NaN         NaN         NaN      NaN
# 2                  NaN  2024-03-30   yearly   110727.00   135327.00      USD
# 3                  NaN  2024-03-30      NaN         NaN         NaN      NaN
# 4                  NaN  2024-03-30   yearly    50573.00    79932.00      USD
# 5                  NaN  2024-03-30   hourly       85.00       90.00      USD
# 6                  NaN  2024-03-30   yearly    87792.00   117536.00      USD
# 7                  NaN  2024-03-30   hourly       52.00       59.00      USD
# 8                  NaN  2024-03-30   yearly    80000.00   130000.00      USD
# 9                  NaN  2024-03-30   yearly    55000.00    70000.00      USD
# 10                 NaN  2024-03-30   yearly    45000.00    45000.00      USD
# 11                 NaN  2024-03-30   yearly    75000.00   100000.00      USD
# 12                 NaN  2024-03-30   yearly    80000.00   140000.00      USD
# 13                 NaN  2024-03-30   yearly    90000.00   100000.00      USD
# 14                 NaN  2024-03-30   yearly   153900.00   153900.00      USD
# 15                 NaN  2024-03-30   yearly    99956.00   120377.00      USD
# 16                 NaN  2024-03-30   yearly    60000.00    70000.00      USD
# 17                 NaN  2024-03-30   yearly    99694.00   138140.00      USD
# 18                 NaN  2024-03-30      NaN         NaN         NaN      NaN
# 19                 NaN  2024-03-30   yearly   160000.00   185000.00      USD
# 20                 NaN  2024-03-30   yearly   120000.00   150000.00      USD
# 21                 NaN  2024-03-30   yearly    70057.00   108142.00      USD
# 22                 NaN  2024-03-30   yearly   120000.00   130000.00      USD
# 23                 NaN  2024-03-30   yearly    92000.00   142000.00      USD
# 24                 NaN  2024-03-30      NaN         NaN         NaN      NaN
# 25            fulltime  2024-03-30      NaN         NaN         NaN      NaN
# 26            fulltime  2024-03-30   hourly       17.00       19.00      USD
# 27            fulltime  2024-03-29      NaN         NaN         NaN      NaN
# 28            fulltime  2024-03-29   yearly    90000.00   140000.00      USD
# 29            fulltime  2024-03-29   yearly    73182.49    98071.22      USD
# 30                 NaN  2024-03-29      NaN         NaN         NaN      NaN
# 31                 NaN  2024-03-29      NaN         NaN         NaN      NaN
# 32            fulltime  2024-03-29      NaN         NaN         NaN      NaN
# 33            fulltime  2024-03-29   yearly    75570.00   128480.00      USD
# 34            fulltime  2024-03-29   hourly         NaN         NaN      USD
# 35            fulltime  2024-03-29   hourly       26.24       35.19      USD
# 36  fulltime, contract  2024-03-29   yearly   100000.00   120000.00      USD
# 37  fulltime, contract  2024-03-29   yearly    62423.00   120562.00      USD
# 38            fulltime  2024-03-29      NaN         NaN         NaN      NaN
# 39          internship  2024-03-29   hourly       12.90       19.35      USD
# 40                 NaN  2024-03-29      NaN         NaN         NaN      NaN
# 41                 NaN  2024-03-29   yearly    51320.27    93000.18      USD
# 42            fulltime  2024-03-29      NaN         NaN         NaN      NaN
# 43            fulltime  2024-03-29   yearly    59000.00    73000.00      USD
# 44            fulltime  2024-03-29   hourly       28.79       41.78      USD
# 45                 NaN  2024-03-29      NaN         NaN         NaN      NaN
# 46                 NaN  2024-03-29      NaN         NaN         NaN      NaN
# 47                 NaN  2024-03-29      NaN         NaN         NaN      NaN
# 73                 NaN  2024-03-30      NaN         NaN         NaN      NaN
# 74                 NaN  2024-03-29      NaN         NaN         NaN      NaN
#
#    is_remote                                        emails  \
# 0      False                                           NaN
# 1       True                                           NaN
# 2       True                                           NaN
# 3       True                                           NaN
# 4      False                                           NaN
# 5       True                                           NaN
# 6      False                                           NaN
# 7       True                                           NaN
# 8       True                    Recruiting@crowdstrike.com
# 9       True                                           NaN
# 10     False                                           NaN
# 11      True                                           NaN
# 12      True                                           NaN
# 13     False                                           NaN
# 14      True                               careers@zoom.us
# 15      True                                           NaN
# 16      True                                           NaN
# 17     False                                           NaN
# 18      True                                           NaN
# 19      True                                           NaN
# 20      True                                           NaN
# 21     False                                           NaN
# 22     False                                           NaN
# 23      True                                           NaN
# 24      True  suresh@arcgonline.com, suresh@arcgonline.com
# 25     False                                           NaN
# 26     False                                           NaN
# 27     False                                           NaN
# 28     False                           info@cgsfederal.com
# 29     False                                           NaN
# 30     False                                           NaN
# 31     False                                           NaN
# 32      True                           careers@mantech.com
# 33      True                                           NaN
# 34     False                                           NaN
# 35     False                                           NaN
# 36     False                                           NaN
# 37     False                                           NaN
# 38     False                                           NaN
# 39     False                                           NaN
# 40     False                                           NaN
# 41     False                                           NaN
# 42      True                                           NaN
# 43     False                                           NaN
# 44      True                                           NaN
# 45      True                          careers@axleinfo.com
# 46      True                 recruiting@greenwayhealth.com
# 47      True                                           NaN
# 73       NaN                                           NaN
# 74       NaN                                           NaN
#
#                                           description  \
# 0   Penguin Random House is on the lookout for a s...
# 1   The Software Test Engineer is a key member of ...
# 2   Overall, 6-10Go Lang experience of 3-4 years**...
# 3   **Who We Are:**  Omatic solutions are purpose-...
# 4   **Requisition Number: 96481**  Insight Enterpr...
# 5   ### **About Zipline**Zipline is at the forefro...
# 6   Data Concepts is seeking a UI Developer experi...
# 7   Title: Java backend developerLocation: Dallas,...
# 8   #WeAreCrowdStrike and our mission is to stop b...
# 9   This position is US remote based position. Mus...
# 10  **Summary**  This is a great opportunity to jo...
# 11  Overview:  This is a remote position. Must be ...
# 12  **About Aerostrat**Aerostrat is a fast growing...
# 13  **JOB SUMMARY**As a key contributor in the exc...
# 14  **What you can expect**As an AI Engineer, you ...
# 15  Skill: Python DeveloperPython API developer wi...
# 16  **** Applicants must reside in and be legally ...
# 17  **EMPLOYER:** Optum Services, Inc.    **JOB TI...
# 18  Higharc is a VC-backed startup that is changin...
# 19  Cofactr is on a mission to make hardware as ag...
# 20  **Join a Cutting-Edge Healthcare Startup Revol...
# 21  **What is your role?**  **As a Back-end Engine...
# 22  Staff Software Engineer - Full Stack**This is ...
# 23  Overview:**We are*****CONNECTING HEALTH AND WE...
# 24  **REACTJS/NODEJS DEVELOPER – REMOTE**    ARC G...
# 25  ##### **Introduction**Are you passionate about...
# 26  Paths is a full-scale, vertically integrated a...
# 27  ##### **Introduction**Do you have the career o...
# 28  Senior Oracle APEX DeveloperEmployment Type: F...
# 29  **Description**---------------**TENTATIVE RECR...
# 30  Are you an experienced, passionate pioneer in ...
# 31  Are you an experienced, passionate pioneer in ...
# 32  **Secure our Nation, Ignite your Future**Becom...
# 33  **Job Description**  BAE Systems is looking fo...
# 34  GSL Properties, Inc. has an immediate opening ...
# 35  **GENERAL STATEMENT OF DUTIES**  Perform vario...
# 36  ***.Net/Oracle Developer/ MS SQL Developer****...
# 37  *Responsibilities:** Recommend, design, develo...
# 38  AspenTech is a global software leader helping ...
\
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25               http://www.hcahealthcare.com
# 26                                        NaN
# 27               http://www.hcahealthcare.com
# 28                                        NaN
# 29                 https://www.ci.tracy.ca.us
# 30                    http://www.deloitte.com
# 31                    http://www.deloitte.com
# 32                     http://www.mantech.com
# 33  https://www.baesystems.com/en/our-company
# 34              http://www.gslproperties.com/
# 35                http://www.co.marion.or.us/
# 36                                        NaN
# 37                                        NaN
# 38                        http://www.osii.com
# 39                     https://illumifin.com/
# 40                    http://www.deloitte.com
# 41                 https://www.myflorida.com/
# 42                         http://www.wsp.com
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46              http://www.greenwayhealth.com
# 47                    http://www.deloitte.com
# 73                                        NaN
# 74                                        NaN
#
#                                     company_addresses  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                      Nashville, TN
# 26                                                NaN
# 27                                      Nashville, TN
# 28                                                NaN
# 29                                              Tracy
# 30                                       New York, NY
# 31                                       New York, NY
# 32                                        Herndon, VA
# 33                                    London, England
# 34  Three Centerpointe Drive Suite #130\r\nLake Os...
# 35                                       Oregon, USA
# 36                                                NaN
# 37                                                NaN
# 38                                    Minneapolis, MN
# 39                         Greenville, South Carolina
# 40                                       New York, NY
# 41                                    Tallahassee, FL
# 42  1600 BOULEVARD RENÉ-LÉVESQUE WEST, 11TH FLOOR\...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                          Tampa, FL
# 47                                       New York, NY
# 73                                                NaN
# 74                                                NaN
#
#                      company_industry company_num_employees  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
# 5                                 NaN                   NaN
# 6                                 NaN                   NaN
# 7                                 NaN                   NaN
# 8                                 NaN                   NaN
# 9                                 NaN                   NaN
# 10                                NaN                   NaN
# 11                                NaN                   NaN
# 12                                NaN                   NaN
# 13                                NaN                   NaN
# 14                                NaN                   NaN
# 15                                NaN                   NaN
# 16                                NaN                   NaN
# 17                                NaN                   NaN
# 18                                NaN                   NaN
# 19                                NaN                   NaN
# 20                                NaN                   NaN
# 21                                NaN                   NaN
# 22                                NaN                   NaN
# 23                                NaN                   NaN
# 24                                NaN                   NaN
# 25                                NaN               10,000+
# 26                                NaN                   NaN
# 27                                NaN               10,000+
# 28                                NaN                   NaN
# 29                         Government            201 to 500
# 30                                NaN               10,000+
# 31                                NaN               10,000+
# 32                                NaN       5,001 to 10,000
# 33                                NaN               10,000+
# 34                                NaN             51 to 200
# 35                         Government        1,001 to 5,000
# 36                                NaN                   NaN
# 37                                NaN                   NaN
# 38                                NaN        1,001 to 5,000
# 39                                NaN        1,001 to 5,000
# 40                                NaN               10,000+
# 41                         Government            201 to 500
# 42   Consulting And Business Services       5,001 to 10,000
# 43                                NaN                   NaN
# 44                                NaN                   NaN
# 45                                NaN                   NaN
# 46                                NaN        1,001 to 5,000
# 47                                NaN               10,000+
# 73                                NaN                   NaN
# 74                                NaN                   NaN
#
#          company_revenue                                company_description  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# 5                    NaN                                                NaN
# 6                    NaN                                                NaN
# 7                    NaN                                                NaN
# 8                    NaN                                                NaN
# 9                    NaN                                                NaN
# 10                   NaN                                                NaN
# 11                   NaN                                                NaN
# 12                   NaN                                                NaN
# 13                   NaN                                                NaN
# 
\
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6                                                 NaN               NaN
# 7                                                 NaN               NaN
# 8                                                 NaN               NaN
# 9                                                 NaN               NaN
# 10                                                NaN               NaN
# 11                                                NaN               NaN
# 12                                                NaN               NaN
# 13                                                NaN               NaN
# 14                                                NaN               NaN
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN               NaN
# 18                                                NaN               NaN
# 19                                                NaN               NaN
# 20                                                NaN               NaN
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23                                                NaN               NaN
# 24                                                NaN               NaN
# 25  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 26                                                NaN               NaN
# 27  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 28                                                NaN               NaN
# 29                                                NaN               NaN
# 30  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 31  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 32  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 33  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 34                                                NaN               NaN
# 35                                                NaN               NaN
# 36                                                NaN               NaN
# 37                                                NaN               NaN
# 38                                                NaN               NaN
# 39                                                NaN               NaN
# 40  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 41                                                NaN               NaN
# 42  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 43                                                NaN               NaN
# 44                                                NaN               NaN
# 45                                                NaN               NaN
# 46  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 47  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...               NaN
# 73                                                NaN               NaN
# 74                                                NaN               NaN
#
#     benefits  id                                   full_description
# 0        NaN   0  Senior .NET/C# Developer (Open to Remote) Peng...
# 1        NaN   1  REMOTE - Sr. Software Test Engineer The Softwa...
# 2        NaN   2  Golang Developer Overall, 6-10Go Lang experien...
# 3        NaN   3  Software Development Engineer In Test (SEDT) *...
# 4        NaN   4  Outlook Add-In (C#) Developer **Requisition Nu...
# 5        NaN   5  Frontend Software Engineer (Contractor) ### **...
# 6        NaN   6  UI Developer Data Concepts is seeking a UI Dev...
# 7        NaN   7  Java Backend Developer Title: Java backend dev...
# 8        NaN   8  Exam Developer (Remote) #WeAreCrowdStrike and ...
# 9        NaN   9  Junior E-Commerce Developer This position is U...
# 10       NaN  10  Web Developer **Summary**  This is a great opp...
# 11       NaN  11  E-Commerce Web Developer Overview:  This is a ...
# 12       NaN  12  Software Engineer (Frontend) **About Aerostrat...
# 13       NaN  13  Software Developer (Remote- US- Atlanta, GA Ba...
# 14       NaN  14  AI Software Engineer **What you can expect**As...
# 15       NaN  15  Python Developer Skill: Python DeveloperPython...
# 16       NaN  16  WordPress Specialist & Administrator **** Appl...
# 17       NaN  17  Software Engineer - 2219704 **EMPLOYER:** Optu...
# 18       NaN  18  Senior Frontend Engineer Higharc is a VC-backe...
# 19       NaN  19  Software Engineer, Data Team Cofactr is on a m...
# 20       NaN  20  Software Engineer **Join a Cutting-Edge Health...
# 21       NaN  21  Back-End Engineer **What is your role?**  **As...
# 22       NaN  22  Staff Software Engineer FS Staff Software Engi...
# 23       NaN  23  Software Engineer II Overview:**We are*****CON...
# 24       NaN  24  Node JS Developer **REACTJS/NODEJS DEVELOPER –...
# 25       NaN  25  Senior System Engineer ##### **Introduction**A...
# 26       NaN  26  Recertification Specialist Paths is a full-sca...
# 27       NaN  27  Associate Database Administrator ##### **Intro...
# 28       NaN  28  Senior Oracle APEX Developer Senior Oracle APE...
# 29       NaN  29  Engineering Technician I/II **Description**---...
# 30       NaN  30  US E- Consulting- IBM Datacap Developer - Solu...
# 31       NaN  31  US E- Consulting- Senior IBM Datacap Developer...
# 32       NaN  32  Integration Layer Data Engineer **Secure our N...
# 33       NaN  33  Division Training Officer Instructor/Developer...
# 34       NaN  34  Accounting Assistant GSL Properties, Inc. has ...
# 35       NaN  35  Survey Technician 2 - Public Works **GENERAL S...
# 36       NaN  36  .Net Developer ***.Net/Oracle Developer/ MS SQ...
# 37       NaN  37  Geographical Information System (GIS) Develope...
# 38       NaN  38  Associate Manager, Software Development AspenT...
# 39       NaN  39  Intern- PHP Developer The PHP intern is respon...
# 40       NaN  40  ServiceNow Developer - TS/SCI Poly Required Ar...
# 41       NaN  41  DATA BASE ADMINISTRATOR - SES Requisition No: ...
# 42       NaN  42  Senior Traffic Engineer This OpportunityWSP is...
# 43       NaN  43  Planner 1 **Overview:**  We are seeking a skil...
# 44       NaN  44  Development Engineer East Cherry Creek Valley ...
# 45       NaN  45  Clinical Research Coordinator **Axle** is a bi...
# 46       NaN  46  Associate Software Engineer (Remote Opportunit...
# 47       NaN  47  Project Delivery Specialist - PostgreSQL Devel...
# 73       NaN  73  React Developer (No C2C)- REMOTE React Develop...
# 74       NaN  74  .Net FullStack Developer Responsibilities--- A...

# %%
jobs = jobs[~(jobs['description'].str.lower().isin(['', 'none', 'nan']))]

# Then, filter out rows where 'title' is not empty
jobs = jobs[jobs['title'] != '']
jobs.shape
# Out:
# (441, 30)

# %%
condition = jobs['description'].fillna('').str.endswith('...')
jobs = jobs[~condition]
jobs.shape
# Out:
# (441, 30)

# %%
jobs = jobs.dropna(subset=['description'])

jobs['full_description'] = jobs['title'].astype(str) + ' ' + jobs['description'].astype(str)
jobs.shape
# Out:
# (441, 30)

# %%
jobs['description'] = jobs['description'].replace({
    r'\n': '',  # Raw string notation
    r'\t': '',  # Raw string notation
    r'\\': '',  # Double backslash to match a single backslash in the text
    '/': '/',   # Normal slash, doesn't need escaping
    '\u00b7': '',  # Direct Unicode character, no need for escaping
    '\u2019': '',  # Direct Unicode character, no need for escaping
    '\u00a0': ''   # Direct Unicode character, no need for escaping
}, regex=True)

# %%
jobs['id'] = jobs.index

# %%
selected_columns = ['id', 'full_description']
jobs_train = jobs[selected_columns]
jobs_train.head(5)
# Out:
#    id                                   full_description
# 0   0  Senior .NET/C# Developer (Open to Remote) Peng...
# 1   1  REMOTE - Sr. Software Test Engineer The Softwa...
# 2   2  Golang Developer Overall, 6-10Go Lang experien...
# 3   3  Software Development Engineer In Test (SEDT) *...
# 4   4  Outlook Add-In (C#) Developer **Requisition Nu...

# %% [markdown]
# # NLP
# In the endeavor to refine the job search process, the implementation of Natural Language Processing (NLP) stands as a cornerstone for extracting and analyzing nuanced information from job descriptions. This essay delineates the meticulous steps involved in deploying NLP to categorize jobs accurately based on experience levels and specific qualifications, thus enhancing the precision and efficiency of job matching.
#
# Preprocessing: The Foundation of Text Analysis
# The journey begins with preprocessing, a critical phase where textual data undergoes a transformation to become conducive to analysis. This phase involves converting all text to lowercase to ensure consistency across the dataset. Subsequently, the text is tokenized, breaking down the job descriptions into individual words or tokens, laying the groundwork for a granular examination of the content. Common words, known as stop words, which hold minimal analytical value, are removed. Additionally, stemming or lemmatization processes are applied, standardizing words to their root form. This preprocessing not only cleans the data but also harmonizes it, setting a robust foundation for the intricate analysis to follow.
#
# Feature Extraction: Unearthing Relevant Information
# With the data primed, the focus shifts to feature extraction, a pivotal step where the trained NLP model identifies and extracts phrases and terms pivotal for categorizing jobs by experience level and qualifications. Techniques such as Named Entity Recognition (NER) are employed to classify key pieces of information into predefined categories, while pattern matching, especially through the use of regular expressions, aids in identifying specific expressions related to job qualifications, such as years of required experience.
#
# Leveraging Pre-trained Models: A Shortcut to Depth
# The utilization of pre-trained models like BERT or GPT marks a significant leap in the analysis. These models, having been trained on vast expanses of text, possess a profound understanding of language nuances. By fine-tuning these models for specific tasks, such as text classification or entity recognition, they become adept at classifying job descriptions into precise categories (entry-level, mid-level, senior-level) and extracting detailed requirements (years of experience, required skills, educational qualifications).
#
# Post-processing and Categorization: The Art of Interpretation
# The extracted information undergoes post-processing, where it is analyzed and mapped to specific categories. This process involves not just the categorization of jobs based on experience level but also the quantification of qualitative data, such as converting phrases indicating years of experience into numerical values. This nuanced interpretation and categorization enable the development of a sophisticated job filtering and search mechanism, directly addressing the needs and qualifications of job seekers.
#
# Implementation and Integration: Bringing Analysis to Action
# The final stride in this journey is the integration of the processed and categorized data into the job finding platform. This crucial phase ensures that the insights gleaned from the NLP analysis directly enhance the platform's functionality, allowing users to navigate through job listings with unparalleled precision. The implementation of NLP thus transcends mere analysis, embodying a transformation in how job seekers connect with potential opportunities, making the search for the perfect job not just faster but significantly more meaningful.
#
# In essence, the application of NLP within the job search domain is a testament to the power of language processing in bridging the gap between job seekers and the roles they aspire to fill. By meticulously preprocessing text, extracting relevant features, leveraging advanced models, and integrating these insights into job search platforms, the project not only simplifies the job search process but elevates it, ensuring that every job seeker finds their rightful place in the professional world.

# %%
# Only necessary once to get the input to finetoon the model
input_for_bert = jobs_train.sample(n=50)
input_for_bert.to_json('./input_for_bert.json', orient='records', lines=True)

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.39.2-py3-none-any.whl.metadata (134 kB)
#      ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/134.8 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/134.8 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/134.8 kB 262.6 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/134.8 kB 281.8 kB/s eta 0:00:01
#      ------------------------------ ----- 112.6/134.8 kB 595.3 kB/s eta 0:00:01
#      ------------------------------------ 134.8/134.8 kB 666.3 kB/s eta 0:00:00
# Collecting filelock (from transformers)
#   Downloading filelock-3.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from transformers) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2023.12.25-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.2-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.19.3->transformers)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: colorama in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.39.2-py3-none-any.whl (8.8 MB)
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.8 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/8.8 MB 6.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.8 MB 10.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.2/8.8 MB 13.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.8/8.8 MB 18.6 MB/s eta 0:00:01
#    ------------------------- -------------- 5.5/8.8 MB 23.5 MB/s eta 0:00:01
#    ------------------------------------- -- 8.2/8.8 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 28.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#    ---------------------------------------- 0.0/388.9 kB ? eta -:--:--
#    ---------------------------------------- 388.9/388.9 kB ? eta 0:00:00
# Downloading regex-2023.12.25-cp311-cp311-win_amd64.whl (269 kB)
#    ---------------------------------------- 0.0/269.5 kB ? eta -:--:--
#    --------------------------------------- 269.5/269.5 kB 17.3 MB/s eta 0:00:00
# Downloading safetensors-0.4.2-cp311-none-win_amd64.whl (269 kB)
#    ---------------------------------------- 0.0/269.6 kB ? eta -:--:--
#    ---------------------------------------- 269.6/269.6 kB ? eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------  2.2/2.2 MB 70.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 46.4 MB/s eta 0:00:00
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.5 MB/s eta 0:00:00
# Downloading filelock-3.13.3-py3-none-any.whl (11 kB)
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ---------------------------------------- 0.0/172.0 kB ? eta -:--:--
#    --------------------------------------- 172.0/172.0 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: tqdm, safetensors, regex, fsspec, filelock, huggingface-hub, tokenizers, transformers
# Successfully installed filelock-3.13.3 fsspec-2024.3.1 huggingface-hub-0.22.2 regex-2023.12.25 safetensors-0.4.2 tokenizers-0.15.2 tqdm-4.66.2 transformers-4.39.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: torchvision in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (0.17.2)
# Requirement already satisfied: torchaudio in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: filelock in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# 2.2.2+cpu
# CUDA available: False
# GPU: None

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\bouch\appdata\local\programs\python\python311\lib\site-packages (24.0)

# %%
import torch
print(torch.__version__)
# Out:
# 2.2.2+cpu

# %%
from transformers import BertForTokenClassification

model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=4)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[71], line 3
#       1 from transformers import BertForTokenClassification
# ----> 3 model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=4)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1412, in DummyObject.__getattribute__(cls, key)
#    1410 if key.startswith("_") and key != "_from_config":
#    1411     return super().__getattribute__(key)
# -> 1412 requires_backends(cls, cls._backends)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1400, in requires_backends(obj, backends)
#    1398 failed = [msg.format(name) for available, msg in checks if not available()]
#    1399 if failed:
# -> 1400     raise ImportError("".join(failed))
#
# ImportError:
# BertForTokenClassification requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %%
from transformers import BertForTokenClassification

model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=4)  # Adjust num_labels as necessary
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 3
#       1 from transformers import BertForTokenClassification
# ----> 3 model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=4)  # Adjust num_labels as necessary
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1412, in DummyObject.__getattribute__(cls, key)
#    1410 if key.startswith("_") and key != "_from_config":
#    1411     return super().__getattribute__(key)
# -> 1412 requires_backends(cls, cls._backends)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1400, in requires_backends(obj, backends)
#    1398 failed = [msg.format(name) for available, msg in checks if not available()]
#    1399 if failed:
# -> 1400     raise ImportError("".join(failed))
#
# ImportError:
# BertForTokenClassification requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %% [markdown]
# # Logistic Regression
#
# In the realm of talent acquisition and career progression, the task of sorting job postings into various career levels represents a fundamental challenge. With an ever-growing pool of opportunities and candidates, efficiently categorizing these postings is crucial for both job seekers and employers. Leveraging machine learning techniques, particularly logistic regression, presents a pragmatic approach to address this challenge effectively.
#
# At the core of the task lies a dataset comprising approximately 500 job postings, each characterized by a set of features including salary, years of experience, degree requirements, and career level indicators. The primary objective is to categorize these postings into distinct career levels such as entry-level, mid-level, and senior-level roles.
#
# From a practical standpoint, logistic regression emerges as the optimal choice for several compelling reasons. Firstly, its inherent interpretability offers invaluable insights into the relationships between features and the predicted career levels. In the context of talent acquisition, understanding the influential factors driving career progression is paramount. Logistic regression allows stakeholders to discern the impact of individual features, thereby facilitating informed decision-making processes.
#
# Moreover, logistic regression's simplicity and computational efficiency align seamlessly with the project's constraints. With a dataset of modest size, the need for a model that balances performance with resource utilization becomes apparent. Logistic regression fulfills this requirement admirably, offering respectable predictive capabilities without necessitating extensive computational resources or complex tuning procedures.
#
# Furthermore, logistic regression's versatility in handling categorical features is particularly advantageous. In the context of job postings, where attributes such as degree requirements and career levels are inherently categorical, logistic regression seamlessly accommodates these variables. This eliminates the need for elaborate preprocessing steps, streamlining the model development process and expediting time-to-insight.
#
# Additionally, logistic regression's amenability to regularization techniques further enhances its suitability for the task at hand. By applying techniques such as L1 (Lasso) or L2 (Ridge) regularization, the risk of overfitting inherent in small datasets is mitigated effectively. This ensures that the model maintains robust performance and generalizability, even in the presence of limited data.
#
# In summary, the decision to employ logistic regression for the classification of job postings into career levels represents a pragmatic and well-founded approach. By prioritizing interpretability, simplicity, and computational efficiency, logistic regression enables stakeholders to glean actionable insights from the dataset while achieving respectable predictive performance. As the landscape of talent acquisition continues to evolve, logistic regression stands as a steadfast tool for navigating the complexities of job posting classification with confidence and efficacy.
