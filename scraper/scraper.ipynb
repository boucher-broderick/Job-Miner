# %% [markdown]
# # Introduction
# Job postings can often times be missleading, as an entry level position can require candadits to have 5+ years of experience, and because of this it can seem like you are spending more time looking for jobs than applying. The goal of this program is to take job postings from various job posting services and finding

# %%
from jobspy import scrape_jobs
import pandas as pd

# %%
jobs: pd.DataFrame = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    search_term="entry level developer",
    location="Dallas, TX",
    results_wanted=25,  # be wary the higher it is, the more likey you'll get blocked (rotating proxy can help tho)
    country_indeed="USA",
    # proxy="http://jobspy:5a4vpWtj8EeJ2hoYzk@ca.smartproxy.com:20001",
)

# formatting for pandas
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", 50)  # set to 0 to see full job url / desc


print(jobs)
# Out:
#                                               job_url           site  \
# 43  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 27  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 29  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 40  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 46  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 25  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 44  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 30  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 36  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 31  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 28  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 33  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# 26  https://www.glassdoor.com/job-listing/j?jl=100...      glassdoor
# ...

# %%
new_data = jobs
existing_data = pd.read_json("./jobs.json", lines=True)
current_data = pd.concat([new_data, existing_data], ignore_index=True)
jobs = current_data

# %%
jobs.shape
# Out:
# (175, 17)
